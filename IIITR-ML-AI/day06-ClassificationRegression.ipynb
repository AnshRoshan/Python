# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data/Algerian_forest_fires_dataset.csv")
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# 2    0.1   not fire
# 3      0   not fire
# 4    0.5   not fire
# ..   ...           ...
# 242  6.5       fire
# 243    0   not fire
# 244  0.2   not fire
# 245  0.7   not fire
# 246  0.5  not fire
#
# [247 rows x 14 columns]

# %%
df.drop([122,123,124],inplace=True)
df.reset_index(inplace=True)
df.drop('index',axis=1,inplace=True)
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# 2    0.1   not fire
# 3      0   not fire
# 4    0.5   not fire
# ..   ...           ...
# 239  6.5       fire
# 240    0   not fire
# 241  0.2   not fire
# 242  0.7   not fire
# 243  0.5  not fire
#
# [244 rows x 14 columns]

# %%
df.loc[:'244','region']='region'
df.loc[:'244','region']='sidi-belie'
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes        region
# 0    0.5   not fire     sidi-belie
# 1    0.4   not fire     sidi-belie
# 2    0.1   not fire     sidi-belie
# 3      0   not fire     sidi-belie
# 4    0.5   not fire     sidi-belie
# ..   ...           ...         ...
# 239  6.5       fire     sidi-belie
# 240    0   not fire     sidi-belie
# 241  0.2   not fire     sidi-belie
# 242  0.7   not fire     sidi-belie
# 243  0.5  not fire      sidi-belie
#
# [244 rows x 15 columns]

# %%
df.columns=[i.strip() for i in df.columns ]
df.columns
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI       Classes      region
# 0    0.5   not fire     sidi-belie
# 1    0.4   not fire     sidi-belie
# 2    0.1   not fire     sidi-belie
# 3      0   not fire     sidi-belie
# 4    0.5   not fire     sidi-belie
# ..   ...           ...         ...
# 239  6.5       fire     sidi-belie
# 240    0   not fire     sidi-belie
# 241  0.2   not fire     sidi-belie
# 242  0.7   not fire     sidi-belie
# 243  0.5  not fire      sidi-belie
#
# [244 rows x 15 columns]

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes      region
# 0  not fire     sidi-belie
# 1  not fire     sidi-belie
# 2  not fire     sidi-belie
# 3  not fire     sidi-belie
# 4  not fire     sidi-belie

# %%
df.drop('Classes',axis=1,inplace=True)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI      region
# 0    0.5  sidi-belie
# 1    0.4  sidi-belie
# 2    0.1  sidi-belie
# 3      0  sidi-belie
# 4    0.5  sidi-belie
# ..   ...         ...
# 239  6.5  sidi-belie
# 240    0  sidi-belie
# 241  0.2  sidi-belie
# 242  0.7  sidi-belie
# 243  0.5  sidi-belie
#
# [244 rows x 14 columns]

# %%
# df.drop([122], axis=0, inplace=True)
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI      region
# 0    0.5  sidi-belie
# 1    0.4  sidi-belie
# 2    0.1  sidi-belie
# 3      0  sidi-belie
# 4    0.5  sidi-belie
# ..   ...         ...
# 239  6.5  sidi-belie
# 240    0  sidi-belie
# 241  0.2  sidi-belie
# 242  0.7  sidi-belie
# 243  0.5  sidi-belie
#
# [244 rows x 14 columns]

# %%
df['date']=pd.to_datetime(df[['day','month','year']])
df
# Out:
#     day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI      region       date
# 0    0.5  sidi-belie 2012-06-01
# 1    0.4  sidi-belie 2012-06-02
# 2    0.1  sidi-belie 2012-06-03
# 3      0  sidi-belie 2012-06-04
# 4    0.5  sidi-belie 2012-06-05
# ..   ...         ...        ...
# 239  6.5  sidi-belie 2012-09-26
# 240    0  sidi-belie 2012-09-27
# 241  0.2  sidi-belie 2012-09-28
# 242  0.7  sidi-belie 2012-09-29
# 243  0.5  sidi-belie 2012-09-30
#
# [244 rows x 15 columns]

# %%
df.corr(numeric_only=True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['Temperature']=df['Temperature'].astype(int)
df['RH']=df['RH'].astype(int)
df['Ws']=df['Ws'].astype(int)
df['Rain']=df['Rain'].astype(float)
df['FFMC']=df['FFMC'].astype(float)
df['DMC']=df['DMC'].astype(float)
df['ISI']=df['ISI'].astype(float)
df['BUI']=df['BUI'].astype(float)
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    int32
#  4   RH           244 non-null    int32
#  5   Ws           244 non-null    int32
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  region       244 non-null    object
#  14  date         244 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int32(3), object(6)
# memory usage: 25.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
df['DC']=lb.fit_transform(df['DC'])
df['FWI']=lb.fit_transform(df['FWI'])
df['region']=lb.fit_transform(df['region'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    int32
#  4   RH           244 non-null    int32
#  5   Ws           244 non-null    int32
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    int32
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    int32
#  13  region       244 non-null    int32
#  14  date         244 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int32(6), object(3)
# memory usage: 23.0+ KB

# %%
df
# Out:
#     day month  year  Temperature  RH  Ws  Rain  FFMC   DMC   DC  ISI   BUI  \
# 0     1     6  2012           29  57  18   0.0  65.7   3.4  150  1.3   3.4
# 1     2     6  2012           29  61  13   1.3  64.4   4.1  150  1.0   3.9
# 2     3     6  2012           26  82  22  13.1  47.1   2.5  146  0.3   2.7
# 3     4     6  2012           25  89  13   2.5  28.6   1.3  136  0.0   1.7
# 4     5     6  2012           27  77  16   0.0  64.8   3.0   18  1.2   3.9
# ..   ..   ...   ...          ...  ..  ..   ...   ...   ...  ...  ...   ...
# 239  26     9  2012           30  65  14   0.0  85.4  16.0  112  4.5  16.9
# 240  27     9  2012           28  87  15   4.4  41.1   6.5  164  0.1   6.2
# 241  28     9  2012           27  87  29   0.5  45.9   3.5  153  0.4   3.4
# 242  29     9  2012           24  54  18   0.1  79.7   4.3   25  1.7   5.1
# 243  30     9  2012           24  64  15   0.2  67.3   3.8   34  1.2   4.8
#
#      FWI  region       date
# 0      5       0 2012-06-01
# 1      4       0 2012-06-02
# 2      1       0 2012-06-03
# 3      0       0 2012-06-04
# 4      5       0 2012-06-05
# ..   ...     ...        ...
# 239  106       0 2012-09-26
# 240    0       0 2012-09-27
# 241    2       0 2012-09-28
# 242    7       0 2012-09-29
# 243    5       0 2012-09-30
#
# [244 rows x 15 columns]

# %%
x=pd.DataFrame(df,columns=['RH','Ws','Rain','FFMC','DMC','DC','ISI','BUI','FWI','region'])
y=pd.DataFrame(df,columns=['Temperature'])
y
# Out:
#      Temperature
# 0             29
# 1             29
# 2             26
# 3             25
# 4             27
# ..           ...
# 239           30
# 240           28
# 241           27
# 242           24
# 243           24
#
# [244 rows x 1 columns]

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=100)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.fit_transform(x_test)

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg_pred=regression.predict(x_test)

# %%
reg_pred
# Out:
# array([[32.62971147],
#        [32.12091658],
#        [35.48283195],
#        [30.12218375],
#        [34.02845873],
#        [31.90711853],
#        [34.38196838],
#        [33.02509838],
#        [28.1695141 ],
#        [34.61764024],
#        [34.60337535],
#        [26.83491164],
#        [33.89684167],
#        [34.18183169],
#        [35.99061263],
#        [33.66088487],
#        [32.6368115 ],
#        [29.57995635],
#        [33.42651964],
#        [33.64863535],
#        [31.59081005],
#        [32.95295941],
#        [32.22851933],
#        [29.20750563],
#        [31.54972637],
#        [34.33695668],
#        [33.60888932],
#        [30.38694433],
#        [34.38696924],
#        [31.69151738],
#        [32.03705079],
#        [30.81307326],
#        [23.78346796],
#        [35.7185006 ],
#        [27.50142156],
#        [30.76742084],
#        [34.9910381 ],
#        [29.64081569],
#        [30.89892825],
#        [30.53820405],
#        [33.57644962],
#        [33.09910291],
#        [36.12256308],
#        [30.83164992],
#        [33.18796708],
#        [24.40155168],
#        [27.70092252],
#        [31.16055859],
#        [32.28519584],
#        [34.54416793],
#        [30.55588006],
#        [29.04194331],
#        [34.05626946],
#        [30.83223681],
#        [33.39746765],
#        [32.46339736],
#        [31.95849239],
#        [27.9484054 ],
#        [33.74381719],
#        [31.27963077],
#        [28.65696084],
#        [34.11549041],
#        [31.13085169],
#        [33.46921537],
#        [30.28514663],
#        [24.62638848],
#        [28.9622139 ],
#        [32.39819225],
#        [30.36452486],
#        [33.14267819],
#        [33.92389909],
#        [31.33599805],
#        [26.66621173],
#        [32.70225087],
#        [30.66049293],
#        [31.56499958],
#        [33.18616971],
#        [35.95883962],
#        [36.20019243],
#        [30.91335539],
#        [33.54840389]])

# %%
sns.displot(reg_pred-y_test)
# Out:
# C:\Users\anshr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anshr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anshr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anshr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anshr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\anshr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\anshr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
print(r2_score(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 5.6454086045556275
# 2.0305808211664678
# 0.47534596087014547
# 2.3760068612181295
